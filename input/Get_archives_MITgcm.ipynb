# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (2.32.2)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2024.6.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
#!/usr/bin/env python3
"""
Script para descargar todos los archivos .txt.gz de los MITgcm-support Archives,
descomprimirlos y agrupar su contenido en un único archivo de texto.

Requisitos:
    pip install requests beautifulsoup4
"""

import os
import re
import gzip
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

BASE_URL = "http://mailman.mitgcm.org/pipermail/mitgcm-support/"

def get_txtgz_links():
    """Extrae los enlaces a archivos .txt.gz desde la página principal."""
    response = requests.get(BASE_URL)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, 'html.parser')
    txtgz_links = []
    # Busca todos los <a> cuyo href termine en .txt.gz
    for a in soup.find_all('a', href=True):
        href = a['href']
        if href.endswith(".txt.gz"):
            full_url = urljoin(BASE_URL, href)
            txtgz_links.append(full_url)
    return txtgz_links

def download_and_decompress(url):
    """Descarga un archivo .txt.gz de la URL y lo descomprime.
    Retorna el contenido en texto (utf-8).
    """
    print(f"Descargando {url} ...")
    response = requests.get(url)
    response.raise_for_status()
    # Descomprimir usando gzip; response.content es de tipo bytes
    try:
        decompressed_bytes = gzip.decompress(response.content)
    except Exception as e:
        print(f"Error al descomprimir {url}: {e}")
        return ""
    # Decodifica (la codificación puede variar; usamos utf-8 por defecto)
    try:
        text = decompressed_bytes.decode('utf-8')
    except UnicodeDecodeError:
        # Si falla, intenta con latin1
        text = decompressed_bytes.decode('latin1')
    return text

def main():
    # Archivo de salida donde se agrupará todo el contenido
    output_filename = "todos_archivos.txt"
    
    links = get_txtgz_links()
    if not links:
        print("No se encontraron archivos .txt.gz en la página.")
        return
    print(f"Se encontraron {len(links)} archivos .txt.gz.")

    # Abre el archivo de salida en modo escritura (sobrescribe si existe)
    with open(output_filename, "w", encoding="utf-8") as outfile:
        for url in links:
            # Extrae el nombre base para usarlo como separador en el output
            file_basename = os.path.basename(url)
            header = f"\n{'='*40}\nArchivo: {file_basename}\n{'='*40}\n"
            outfile.write(header)
            content = download_and_decompress(url)
            outfile.write(content)
            print(f"Procesado: {file_basename}")

    print(f"\nTodos los archivos se han agrupado en: {output_filename}")

if __name__ == "__main__":
    main()
# Out:
# Se encontraron 265 archivos .txt.gz.
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2025-June.txt.gz ...
# Procesado: 2025-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2025-May.txt.gz ...
# Procesado: 2025-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2025-April.txt.gz ...
# Procesado: 2025-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2025-March.txt.gz ...
# Procesado: 2025-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2025-February.txt.gz ...
# Procesado: 2025-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2025-January.txt.gz ...
# Procesado: 2025-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-December.txt.gz ...
# Procesado: 2024-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-November.txt.gz ...
# Procesado: 2024-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-October.txt.gz ...
# Procesado: 2024-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-September.txt.gz ...
# Procesado: 2024-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-August.txt.gz ...
# Procesado: 2024-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-July.txt.gz ...
# Procesado: 2024-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-June.txt.gz ...
# Procesado: 2024-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-May.txt.gz ...
# Procesado: 2024-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-April.txt.gz ...
# Procesado: 2024-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-March.txt.gz ...
# Procesado: 2024-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-February.txt.gz ...
# Procesado: 2024-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2024-January.txt.gz ...
# Procesado: 2024-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-December.txt.gz ...
# Procesado: 2023-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-November.txt.gz ...
# Procesado: 2023-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-October.txt.gz ...
# Procesado: 2023-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-September.txt.gz ...
# Procesado: 2023-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-August.txt.gz ...
# Procesado: 2023-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-July.txt.gz ...
# Procesado: 2023-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-June.txt.gz ...
# Procesado: 2023-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-May.txt.gz ...
# Procesado: 2023-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-April.txt.gz ...
# Procesado: 2023-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-March.txt.gz ...
# Procesado: 2023-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-February.txt.gz ...
# Procesado: 2023-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2023-January.txt.gz ...
# Procesado: 2023-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-December.txt.gz ...
# Procesado: 2022-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-November.txt.gz ...
# Procesado: 2022-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-October.txt.gz ...
# Procesado: 2022-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-September.txt.gz ...
# Procesado: 2022-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-August.txt.gz ...
# Procesado: 2022-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-July.txt.gz ...
# Procesado: 2022-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-June.txt.gz ...
# Procesado: 2022-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-May.txt.gz ...
# Procesado: 2022-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-April.txt.gz ...
# Procesado: 2022-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-March.txt.gz ...
# Procesado: 2022-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-February.txt.gz ...
# Procesado: 2022-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2022-January.txt.gz ...
# Procesado: 2022-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-December.txt.gz ...
# Procesado: 2021-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-November.txt.gz ...
# Procesado: 2021-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-October.txt.gz ...
# Procesado: 2021-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-September.txt.gz ...
# Procesado: 2021-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-August.txt.gz ...
# Procesado: 2021-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-July.txt.gz ...
# Procesado: 2021-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-June.txt.gz ...
# Procesado: 2021-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-May.txt.gz ...
# Procesado: 2021-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-April.txt.gz ...
# Procesado: 2021-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-March.txt.gz ...
# Procesado: 2021-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-February.txt.gz ...
# Procesado: 2021-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2021-January.txt.gz ...
# Procesado: 2021-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-December.txt.gz ...
# Procesado: 2020-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-November.txt.gz ...
# Procesado: 2020-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-October.txt.gz ...
# Procesado: 2020-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-September.txt.gz ...
# Procesado: 2020-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-August.txt.gz ...
# Procesado: 2020-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-July.txt.gz ...
# Procesado: 2020-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-June.txt.gz ...
# Procesado: 2020-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-May.txt.gz ...
# Procesado: 2020-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-April.txt.gz ...
# Procesado: 2020-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-March.txt.gz ...
# Procesado: 2020-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-February.txt.gz ...
# Procesado: 2020-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2020-January.txt.gz ...
# Procesado: 2020-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-December.txt.gz ...
# Procesado: 2019-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-November.txt.gz ...
# Procesado: 2019-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-October.txt.gz ...
# Procesado: 2019-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-September.txt.gz ...
# Procesado: 2019-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-August.txt.gz ...
# Procesado: 2019-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-July.txt.gz ...
# Procesado: 2019-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-June.txt.gz ...
# Procesado: 2019-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-May.txt.gz ...
# Procesado: 2019-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-April.txt.gz ...
# Procesado: 2019-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-March.txt.gz ...
# Procesado: 2019-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-February.txt.gz ...
# Procesado: 2019-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2019-January.txt.gz ...
# Procesado: 2019-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-December.txt.gz ...
# Procesado: 2018-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-November.txt.gz ...
# Procesado: 2018-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-October.txt.gz ...
# Procesado: 2018-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-September.txt.gz ...
# Procesado: 2018-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-August.txt.gz ...
# Procesado: 2018-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-July.txt.gz ...
# Procesado: 2018-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-June.txt.gz ...
# Procesado: 2018-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-May.txt.gz ...
# Procesado: 2018-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-April.txt.gz ...
# Procesado: 2018-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-March.txt.gz ...
# Procesado: 2018-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-February.txt.gz ...
# Procesado: 2018-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2018-January.txt.gz ...
# Procesado: 2018-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-December.txt.gz ...
# Procesado: 2017-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-November.txt.gz ...
# Procesado: 2017-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-October.txt.gz ...
# Procesado: 2017-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-September.txt.gz ...
# Procesado: 2017-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-August.txt.gz ...
# Procesado: 2017-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-July.txt.gz ...
# Procesado: 2017-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-June.txt.gz ...
# Procesado: 2017-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-May.txt.gz ...
# Procesado: 2017-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-April.txt.gz ...
# Procesado: 2017-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-March.txt.gz ...
# Procesado: 2017-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-February.txt.gz ...
# Procesado: 2017-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2017-January.txt.gz ...
# Procesado: 2017-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-December.txt.gz ...
# Procesado: 2016-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-November.txt.gz ...
# Procesado: 2016-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-October.txt.gz ...
# Procesado: 2016-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-September.txt.gz ...
# Procesado: 2016-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-August.txt.gz ...
# Procesado: 2016-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-July.txt.gz ...
# Procesado: 2016-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-June.txt.gz ...
# Procesado: 2016-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-May.txt.gz ...
# Procesado: 2016-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-April.txt.gz ...
# Procesado: 2016-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-March.txt.gz ...
# Procesado: 2016-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-February.txt.gz ...
# Procesado: 2016-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2016-January.txt.gz ...
# Procesado: 2016-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-December.txt.gz ...
# Procesado: 2015-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-November.txt.gz ...
# Procesado: 2015-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-October.txt.gz ...
# Procesado: 2015-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-September.txt.gz ...
# Procesado: 2015-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-August.txt.gz ...
# Procesado: 2015-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-July.txt.gz ...
# Procesado: 2015-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-June.txt.gz ...
# Procesado: 2015-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-May.txt.gz ...
# Procesado: 2015-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-April.txt.gz ...
# Procesado: 2015-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-March.txt.gz ...
# Procesado: 2015-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-February.txt.gz ...
# Procesado: 2015-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2015-January.txt.gz ...
# Procesado: 2015-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-December.txt.gz ...
# Procesado: 2014-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-November.txt.gz ...
# Procesado: 2014-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-October.txt.gz ...
# Procesado: 2014-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-September.txt.gz ...
# Procesado: 2014-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-August.txt.gz ...
# Procesado: 2014-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-July.txt.gz ...
# Procesado: 2014-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-June.txt.gz ...
# Procesado: 2014-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-May.txt.gz ...
# Procesado: 2014-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-April.txt.gz ...
# Procesado: 2014-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-March.txt.gz ...
# Procesado: 2014-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-February.txt.gz ...
# Procesado: 2014-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2014-January.txt.gz ...
# Procesado: 2014-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-December.txt.gz ...
# Procesado: 2013-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-November.txt.gz ...
# Procesado: 2013-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-October.txt.gz ...
# Procesado: 2013-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-September.txt.gz ...
# Procesado: 2013-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-August.txt.gz ...
# Procesado: 2013-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-July.txt.gz ...
# Procesado: 2013-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-June.txt.gz ...
# Procesado: 2013-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-May.txt.gz ...
# Procesado: 2013-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-April.txt.gz ...
# Procesado: 2013-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-March.txt.gz ...
# Procesado: 2013-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-February.txt.gz ...
# Procesado: 2013-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2013-January.txt.gz ...
# Procesado: 2013-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-December.txt.gz ...
# Procesado: 2012-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-November.txt.gz ...
# Procesado: 2012-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-October.txt.gz ...
# Procesado: 2012-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-September.txt.gz ...
# Procesado: 2012-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-August.txt.gz ...
# Procesado: 2012-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-July.txt.gz ...
# Procesado: 2012-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-June.txt.gz ...
# Procesado: 2012-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-May.txt.gz ...
# Procesado: 2012-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-April.txt.gz ...
# Procesado: 2012-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-March.txt.gz ...
# Procesado: 2012-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-February.txt.gz ...
# Procesado: 2012-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2012-January.txt.gz ...
# Procesado: 2012-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-December.txt.gz ...
# Procesado: 2011-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-November.txt.gz ...
# Procesado: 2011-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-October.txt.gz ...
# Procesado: 2011-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-September.txt.gz ...
# Procesado: 2011-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-August.txt.gz ...
# Procesado: 2011-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-July.txt.gz ...
# Procesado: 2011-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-June.txt.gz ...
# Procesado: 2011-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-May.txt.gz ...
# Procesado: 2011-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-April.txt.gz ...
# Procesado: 2011-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-March.txt.gz ...
# Procesado: 2011-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-February.txt.gz ...
# Procesado: 2011-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2011-January.txt.gz ...
# Procesado: 2011-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-December.txt.gz ...
# Procesado: 2010-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-November.txt.gz ...
# Procesado: 2010-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-October.txt.gz ...
# Procesado: 2010-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-September.txt.gz ...
# Procesado: 2010-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-August.txt.gz ...
# Procesado: 2010-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-July.txt.gz ...
# Procesado: 2010-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-June.txt.gz ...
# Procesado: 2010-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-May.txt.gz ...
# Procesado: 2010-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-April.txt.gz ...
# Procesado: 2010-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-March.txt.gz ...
# Procesado: 2010-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-February.txt.gz ...
# Procesado: 2010-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2010-January.txt.gz ...
# Procesado: 2010-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-December.txt.gz ...
# Procesado: 2009-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-November.txt.gz ...
# Procesado: 2009-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-October.txt.gz ...
# Procesado: 2009-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-September.txt.gz ...
# Procesado: 2009-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-August.txt.gz ...
# Procesado: 2009-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-July.txt.gz ...
# Procesado: 2009-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-June.txt.gz ...
# Procesado: 2009-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-May.txt.gz ...
# Procesado: 2009-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-April.txt.gz ...
# Procesado: 2009-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-March.txt.gz ...
# Procesado: 2009-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-February.txt.gz ...
# Procesado: 2009-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2009-January.txt.gz ...
# Procesado: 2009-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-December.txt.gz ...
# Procesado: 2008-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-November.txt.gz ...
# Procesado: 2008-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-October.txt.gz ...
# Procesado: 2008-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-September.txt.gz ...
# Procesado: 2008-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-August.txt.gz ...
# Procesado: 2008-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-July.txt.gz ...
# Procesado: 2008-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-June.txt.gz ...
# Procesado: 2008-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-May.txt.gz ...
# Procesado: 2008-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-April.txt.gz ...
# Procesado: 2008-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-March.txt.gz ...
# Procesado: 2008-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-February.txt.gz ...
# Procesado: 2008-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2008-January.txt.gz ...
# Procesado: 2008-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-December.txt.gz ...
# Procesado: 2007-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-November.txt.gz ...
# Procesado: 2007-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-October.txt.gz ...
# Procesado: 2007-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-September.txt.gz ...
# Procesado: 2007-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-August.txt.gz ...
# Procesado: 2007-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-July.txt.gz ...
# Procesado: 2007-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-June.txt.gz ...
# Procesado: 2007-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-May.txt.gz ...
# Procesado: 2007-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-April.txt.gz ...
# Procesado: 2007-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-March.txt.gz ...
# Procesado: 2007-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-February.txt.gz ...
# Procesado: 2007-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2007-January.txt.gz ...
# Procesado: 2007-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-December.txt.gz ...
# Procesado: 2006-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-November.txt.gz ...
# Procesado: 2006-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-October.txt.gz ...
# Procesado: 2006-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-September.txt.gz ...
# Procesado: 2006-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-August.txt.gz ...
# Procesado: 2006-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-July.txt.gz ...
# Procesado: 2006-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-June.txt.gz ...
# Procesado: 2006-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-May.txt.gz ...
# Procesado: 2006-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-April.txt.gz ...
# Procesado: 2006-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-March.txt.gz ...
# Procesado: 2006-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-February.txt.gz ...
# Procesado: 2006-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2006-January.txt.gz ...
# Procesado: 2006-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-December.txt.gz ...
# Procesado: 2005-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-November.txt.gz ...
# Procesado: 2005-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-October.txt.gz ...
# Procesado: 2005-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-September.txt.gz ...
# Procesado: 2005-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-August.txt.gz ...
# Procesado: 2005-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-July.txt.gz ...
# Procesado: 2005-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-June.txt.gz ...
# Procesado: 2005-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-May.txt.gz ...
# Procesado: 2005-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-April.txt.gz ...
# Procesado: 2005-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-March.txt.gz ...
# Procesado: 2005-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-February.txt.gz ...
# Procesado: 2005-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2005-January.txt.gz ...
# Procesado: 2005-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-December.txt.gz ...
# Procesado: 2004-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-November.txt.gz ...
# Procesado: 2004-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-October.txt.gz ...
# Procesado: 2004-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-September.txt.gz ...
# Procesado: 2004-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-August.txt.gz ...
# Procesado: 2004-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-July.txt.gz ...
# Procesado: 2004-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-June.txt.gz ...
# Procesado: 2004-June.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-May.txt.gz ...
# Procesado: 2004-May.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-April.txt.gz ...
# Procesado: 2004-April.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-March.txt.gz ...
# Procesado: 2004-March.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-February.txt.gz ...
# Procesado: 2004-February.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2004-January.txt.gz ...
# Procesado: 2004-January.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2003-December.txt.gz ...
# Procesado: 2003-December.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2003-November.txt.gz ...
# Procesado: 2003-November.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2003-October.txt.gz ...
# Procesado: 2003-October.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2003-September.txt.gz ...
# Procesado: 2003-September.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2003-August.txt.gz ...
# Procesado: 2003-August.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2003-July.txt.gz ...
# Procesado: 2003-July.txt.gz
# Descargando http://mailman.mitgcm.org/pipermail/mitgcm-support/2003-June.txt.gz ...
# Procesado: 2003-June.txt.gz
#
# Todos los archivos se han agrupado en: todos_archivos.txt
