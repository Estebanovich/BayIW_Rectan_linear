# %% [markdown]
# ## How to look at MITgcm netCDF output, an example
#
# You need to install MITgcmutils package (https://pypi.org/project/MITgcmutils/)

# %%
import cmocean as cmo
import matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm
import matplotlib as mpl
import numpy as np
import xarray as xr
import MITgcmutils as MIT
import seaborn as sns

# %%
sns.set_context('notebook')
#outdir = '/Volumes/Esteban_SSD/Maestría/MITgcm/verification/BayIW/run_expand/mnc_0001/'
outdir2 = '/Volumes/Esteban_SSD/Maestría/MITgcm/verification/BayIW/run_expand/mnc_0002/'
outdir_nobay ='/Volumes/Esteban_SSD/Maestría/MITgcm/verification/BayIW/run_expand_nobay/mnc_0001/'

# %%
nc = MIT.mnc_files(outdir2+'state.0000000600.t*.nc')
gr = MIT.mnc_files(outdir2+'grid.t*.nc')
#nc2 = MIT.mnc_files(outdir2+'state.0000000600.t*.nc')
#gr2 = MIT.mnc_files(outdir2+'grid.t*.nc')
#nc_nobay = MIT.mnc_files(outdir_nobay+'state.0000000000.t*.nc')
#gr_nobay = MIT.mnc_files(outdir_nobay+'grid.t*.nc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 nc = MIT.mnc_files(outdir2+'state.0000000600.t*.nc')
# ----> 2 gr = MIT.mnc_files(outdir2+'grid.t*.nc')
#
# File /opt/anaconda3/lib/python3.12/site-packages/MITgcmutils/mnc.py:382, in mnc_files(fpatt, layout)
#     381 def mnc_files(fpatt, layout=None):
# --> 382     return MNC(fpatt, layout)
#
# File /opt/anaconda3/lib/python3.12/site-packages/MITgcmutils/mnc.py:90, in MNC.__init__(self, fpatt, layout, multitime)
#      87 fnames.sort()
#      89 # open files
# ---> 90 self.nc = [ netcdf_file(f,'r') for f in fnames ]
#      92 # global attributes
#      93 # get from first file, but remove/reset tile-specific ones
#      94 self._attributes = getattributes(self.nc[0], _exclude_global)
#
# File /opt/anaconda3/lib/python3.12/site-packages/MITgcmutils/netcdf.py:224, in netcdf_file.__init__(self, filename, mode, mmap, version)
#     221 self._attributes = {}
#     223 if mode == 'r':
# --> 224     self._read()
#
# File /opt/anaconda3/lib/python3.12/site-packages/MITgcmutils/netcdf.py:524, in netcdf_file._read(self)
#     522 self._read_dim_array()
#     523 self._read_gatt_array()
# --> 524 self._read_var_array()
#
# File /opt/anaconda3/lib/python3.12/site-packages/MITgcmutils/netcdf.py:638, in netcdf_file._read_var_array(self)
#     633     self.variables[name] = netcdf_variable(
#     634             data, typecode, size, shape, dimensions, attributes)
#     636 if self.use_mmap:
#     637     # Build nonrec array.
# --> 638     mm = mmap(self.fp.fileno(), nrbegin+nrsize, access=ACCESS_READ)
#     639     nr_array = ndarray.__new__(ndarray, (), dtype=nrdtype, buffer=mm,
#     640             offset=nrbegin, order='C')
#     641     self._fds.append(mm)
#
# ValueError: mmap length is greater than file size

# %%
# Load some grid variables
depth = gr.variables['Depth'][:]
hFacC = gr.variables['HFacC'][:]
XC = gr.variables['XC'][:]
YC = gr.variables['YC'][:]
XG = gr.variables['XG'][:]
YG = gr.variables['YG'][:]
RC = gr.variables['RC'][:]
RL = gr.variables['RL'][:]
mask = np.ma.getmask(np.ma.masked_values(depth, 0))
mask3D = np.ma.getmask(np.ma.masked_values(hFacC[:,:], 0))
time = nc.variables['T'][:102]
timetotal = nc.variables['T'][:]

# %%
nc.variables

# %%
# Plot bathymetry
fig, ax = plt.subplots(1,1)
ax.set_facecolor('tan')
pc = ax.contourf(XC[0,:],np.flip(YC[:,0]),
                np.ma.masked_array(-depth, mask=mask),
                cmap=cmo.cm.deep_r)
cb = plt.colorbar(pc, label='depth (m)')

# %%
time
# Out:
# array([36000., 37200., 38400., 39600., 40800., 42000., 43200., 44400.,
#        45600., 46800., 48000., 49200., 50400., 51600., 52800., 54000.,
#        55200., 56400., 57600., 58800., 60000., 61200., 62400., 63600.,
#        64800., 66000., 67200., 68400., 69600., 70800., 72000.])

# %%
W = nc.variables['W']
W.shape
# Out:
# (31, 40, 320, 272)

# %%
RC[25]
# Out:
# -222.39999999999995

# %%
#Velocidad vertical (W) a los 222.40 m de profundidad.
#poner aspect(1)
for tt in range(0,31,2):
    W = nc.variables['W'][tt,25,:,:]
    plt.pcolormesh(XC[0,:],YC[:,0],W,vmin=-1E-5, vmax=1E-5, cmap=cmo.cm.balance)
    plt.colorbar()
    plt.title(f'time={time[tt]/3600} h')
    plt.show()

# %%
np.shape(W)
# Out:
# (320, 272)

# %%
print(XC[0,100])
print(YC[120,0])
# Out:
# 507704.6500000012
# 180133.2

# %%
XC.shape
print(XC[0,0])
# Out:
# -205000.0

# %%
2*36000
# Out:
# 72000

# %%
nc.variables['T'][:]
# Out:
# array([36000., 37200., 38400., 39600., 40800., 42000., 43200., 44400.,
#        45600., 46800., 48000., 49200., 50400., 51600., 52800., 54000.,
#        55200., 56400., 57600., 58800., 60000., 61200., 62400., 63600.,
#        64800., 66000., 67200., 68400., 69600., 70800., 72000.])

# %%
W = nc.variables['W'][:,:,100,120]
plt.pcolormesh(time/3600,RC,np.transpose(W),vmin=-1E-5, vmax=1E-5, cmap=cmo.cm.balance)
plt.colorbar()
plt.title(f'')
plt.show()
